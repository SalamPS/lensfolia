# %%
from pathlib import Path
from langchain.schema import Document
from langchain_community.vectorstores import SupabaseVectorStore
from langchain_community.document_loaders import TextLoader
from langchain.text_splitter import MarkdownHeaderTextSplitter
from langchain_google_genai import GoogleGenerativeAIEmbeddings
from supabase.client import Client, create_client
from dotenv import load_dotenv
import os

load_dotenv()
# Out:
# True

# %%
class Config:
    GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY") 
    SUPABASE_URL = os.getenv("SUPABASE_URL")
    SUPABASE_ANON_KEY = os.getenv("SUPABASE_ANON_KEY")
    PRODUCT_COLLECTION_NAME = "lensfolia_collection"
    EMBEDDING_MODEL = "models/gemini-embedding-001"

# %%
supabase: Client = create_client(Config.SUPABASE_URL, Config.SUPABASE_ANON_KEY)

# %%
embeddings = GoogleGenerativeAIEmbeddings(
    api_key=Config.GOOGLE_API_KEY,
    model=Config.EMBEDDING_MODEL
)

# %%
all_docs = []

# %%
faq_path = Path("knowledge_base/faq/faq.md")

if faq_path.exists():
    loader = TextLoader(str(faq_path))
    faq_doc = loader.load()[0]
    
    # Split by question (h1)
    splitter = MarkdownHeaderTextSplitter(
        headers_to_split_on=[("#", "question")]
    )
    
    faq_chunks = splitter.split_text(faq_doc.page_content)
    
    for chunk in faq_chunks:
        if not chunk.page_content.strip():
            continue
            
        question = chunk.metadata.get("question", "Unknown")
        
        combined_content = f"Q: {question}\n\nA: {chunk.page_content}"

        all_docs.append(
            Document(
                page_content=combined_content,  # Question + Answer
                metadata={
                    "doc_type": "faq",
                    "question": question,
                }
            )
        )

# %%
all_docs
# Out:
# [Document(metadata={'doc_type': 'faq', 'question': 'Apa itu LensFolia?'}, page_content='Q: Apa itu LensFolia?\n\nA: LensFolia adalah aplikasi diagnosis penyakit tanaman berbasis AI (Artificial Intelligence). Aplikasi ini membantu pengguna mengidentifikasi penyakit tanaman melalui gambar dan memberikan informasi lengkap, tips perawatan, serta rekomendasi produk.'),
#  Document(metadata={'doc_type': 'faq', 'question': 'Fitur Utama LensFolia?'}, page_content='Q: Fitur Utama LensFolia?\n\nA: LensFolia memiliki tiga fitur utama:  \n**Dr. Lensi**  \nDr. Lensi adalah agen AI cerdas yang dapat:\n- Mendeteksi objek dan penyakit pada tanaman dari gambar.\n- Menggunakan pencarian web dan dokumen untuk memberikan informasi penyakit yang lebih luas.\n- Menyediakan ringkasan penyakit, tips perawatan, dan rekomendasi produk yang sesuai.  \n**Lenskipledia**  \nLenskipledia adalah ensiklopedia digital berisi informasi lengkap tentang:\n- Penyakit tanaman\n- Cara perawatan\n- Produk yang bisa digunakan untuk mengatasi masalah pada tanaman  \n**Lensi Diskusi**  \nLensi Diskusi adalah forum komunitas untuk:\n- Berdiskusi tentang penyakit tanaman\n- Berbagi hasil diagnosis dari Dr. Lensi\n- Mendapatkan saran dan dukungan dari pengguna lain'),
#  Document(metadata={'doc_type': 'faq', 'question': 'Bagaimana cara menggunakan Dr. Lensi?'}, page_content='Q: Bagaimana cara menggunakan Dr. Lensi?\n\nA: 1. Ambil atau unggah gambar tanaman yang sakit.\n2. Dr. Lensi akan menganalisis gambar dan memberikan hasil diagnosis.\n3. Lihat ringkasan penyakit, tips perawatan, dan rekomendasi produk.'),
#  Document(metadata={'doc_type': 'faq', 'question': 'Apakah Dr. Lensi bisa mendeteksi semua jenis tanaman?'}, page_content='Q: Apakah Dr. Lensi bisa mendeteksi semua jenis tanaman?\n\nA: Model klasifikasi gambar saat ini hanya mencakup beberapa jenis tanaman. Namun, Dr. Lensi tetap dapat memberikan informasi penyakit lainnya melalui pencarian dokumen dan web.'),
#  Document(metadata={'doc_type': 'faq', 'question': 'Apakah hasil diagnosis bisa disimpan?'}, page_content='Q: Apakah hasil diagnosis bisa disimpan?\n\nA: Ya, hasil diagnosis bisa disimpan dan dibagikan di Lensi Diskusi untuk diskusi lebih lanjut dengan komunitas.'),
#  Document(metadata={'doc_type': 'faq', 'question': 'Apakah LensFolia gratis?'}, page_content='Q: Apakah LensFolia gratis?\n\nA: Sebagian besar fitur tersedia secara gratis. Namun, beberapa fitur lanjutan atau produk rekomendasi mungkin memerlukan biaya tambahan.'),
#  Document(metadata={'doc_type': 'faq', 'question': 'Di mana saya bisa membaca informasi lebih lanjut?'}, page_content='Q: Di mana saya bisa membaca informasi lebih lanjut?\n\nA: Kamu bisa menjelajahi Lenskipledia di dalam aplikasi untuk membaca lebih banyak tentang penyakit dan produk terkait.'),
#  Document(metadata={'doc_type': 'faq', 'question': 'Bagaimana saya bisa bergabung di Lensi Diskusi?'}, page_content='Q: Bagaimana saya bisa bergabung di Lensi Diskusi?\n\nA: Cukup daftar akun di aplikasi LensFolia, dan kamu bisa langsung mulai berdiskusi atau berbagi hasil diagnosis.')]

# %%
docs_path = Path("knowledge_base/products/")
existing_files = {f.name for f in docs_path.glob("*.md")}

if not existing_files:
    raise FileNotFoundError(f"Missing required documents: {existing_files}")

# %%
for file_path in docs_path.glob("*.md"):
    group = file_path.stem  
    loader = TextLoader(str(file_path))
    doc = loader.load()[0]
    splitter = MarkdownHeaderTextSplitter(headers_to_split_on=[("#", "product_name")])
    product_docs = splitter.split_text(doc.page_content)
    
    for pd in product_docs:
        all_docs.append(
            Document(
                page_content=pd.page_content,
                metadata={
                    "doc_type": "product",
                    "product_name": pd.metadata["product_name"],
                    "group": group
                }
            )
        )

# %%
insectidisa_path = Path("knowledge_base/products/insektisida.md")

if insectidisa_path.exists():
    group = "insektisida"
    loader = TextLoader(str(insectidisa_path))
    doc = loader.load()[0]
    splitter = MarkdownHeaderTextSplitter(headers_to_split_on=[("#", "product_name")])
    product_docs = splitter.split_text(doc.page_content)
    
    for pd in product_docs:
        all_docs.append(
            Document(
                page_content=pd.page_content,
                metadata={
                    "doc_type": "product",
                    "product_name": pd.metadata["product_name"],
                    "group": group
                }
            )
        )

# %%
plants_path = Path("knowledge_base/plants/plants.md")
if plants_path.exists():
    loader = TextLoader(str(plants_path))
    plants_doc = loader.load()[0]
   
    # Split by plant (h1) and sections (h2, h3, h4)
    splitter = MarkdownHeaderTextSplitter(
        headers_to_split_on=[
            ("#", "plant_name"),
            ("##", "section"),
            ("###", "subsection"),
            ("####", "disease_name")
        ]
    )
    plant_chunks = splitter.split_text(plants_doc.page_content)
   
    for chunk in plant_chunks:
        # Skip empty content chunks
        if not chunk.page_content.strip():
            continue
           
        # Extract metadata
        plant_name = chunk.metadata.get("plant_name", "Unknown").lower()
        section = chunk.metadata.get("section", "General")
        subsection = chunk.metadata.get("subsection", "")
        disease_name = chunk.metadata.get("disease_name", "")
       
        # Create meaningful section identifier
        section_id = section
        if subsection:
            section_id = f"{section} - {subsection}"
        if disease_name:
            section_id = f"{section} - {disease_name}"
       
        all_docs.append(
            Document(
                page_content=chunk.page_content,
                metadata={
                    "doc_type": "plant_info",
                    "plant_name": plant_name,
                    "section": section_id,
                    "content_type": section.lower().replace(" ", "_")
                }
            )
        )

# %%
print(f"Total documents loaded: {len(all_docs)}")
print("\nDocument types:")
products = [d for d in all_docs if d.metadata["doc_type"] == "product"]
plants = [d for d in all_docs if d.metadata["doc_type"] == "plant_info"]
print(f"Products: {len(products)}")
print(f"Plant info: {len(plants)}")
# Out:
# Total documents loaded: 1987
#
# Document types:
# Products: 56
# Plant info: 1931

# %%
all_docs
# Out:
# [Document(metadata={'doc_type': 'product', 'product_name': 'ANWAVIN 500 EC', 'group': 'insektisida'}, page_content='![Image of product: ANWAVIN 500 EC](https://kresna.co.id/sarikresnakimia/wp-content/uploads/2014/11/Anwavin-500-EC-1000x10001-360x360.png)  \n**Bahan Aktif:** Profenofos 500 g/l  \n**Deskripsi:** Insektisida racun kontak dan perut berbentuk pekatan yang dapat diemulsikan berwarna kuning kecoklatan untuk mengendalikan hama kutu daun ( Myzus Percisae ) dan thrips ( Thrips Parvispinus ) pada tanaman cabai.  \n**Pengaplikasian:** Penyemprotan Volume tinggi dilakukan segera setelah terlihat adanya serangan dan diulang 5 – 10 hari kemudian  \n**Petunjuk Penggunaan:**  \n| Tanaman | Gulma Sasaran | Dosis Anjuran |\n| --- | --- | --- |\n| Cabai | Ulat Grayak (Spodoptera litura) | 1-2 ml/l |\n| Cabai | Ulat Grayak (Spodoptera litura) | 1-2 ml/l |\n| Kubis | Ulat Daun (Plutella xylostella) | 1-2 ml/l |\n| Kubis | Ulat krop (Crocidoloma pavonana) | 1-2 ml/l |  \n---'),
#  Document(metadata={'doc_type': 'product', 'product_name': 'BENTO 50 EC', 'group': 'insektisida'}, page_content='![Image of product: BENTO 50 EC](https://kresna.co.id/sarikresnakimia/wp-content/uploads/2014/11/Bento-50-EC-1000x1000-360x360.png)  \n**Bahan Aktif:** Sipermetrin 50 g/l  \n**Deskripsi:** Insektisida racun kontak dan lambung, berbentuk pekatan berwarna kuning yang dapat membentuk emulsi dalam air untuk mengendalikan ulat grayak ( Spodoptera Litura F. ) pada tanaman cabai, kedelai, dan penggerek buah pada kakao.  \n**Pengaplikasian:** Saat populasi atau intensitas serangan hama telah mencapai sesuai rekomendasi setempat.  \n**Petunjuk Penggunaan:**  \n| Tanaman | Gulma Sasaran | Dosis Anjuran |\n| --- | --- | --- |\n| Cabai | Ulat Grayak (Spodoptera litura) | 0.75 – 0.5 ml/l |\n| Cabai | Ulat Grayak (Spodoptera litura) | 0.75 – 0.5 ml/l |\n| Kedelai | Ulat Grayak (Spodoptera litura) | 0.25 – 0.5 ml/l |\n| Kedelai | Ulat Grayak (Spodoptera litura) | 0.25 – 0.5 ml/l |\n| Kakao | Penggerek Buah Conopomorpha cramerella | 2 ml/l |  \n---'),
#  Document(metadata={'doc_type': 'product', 'product_name': 'BIONIK 400 EC', 'group': 'insektisida'}, page_content='![Image of product: BIONIK 400 EC](https://kresna.co.id/sarikresnakimia/wp-content/uploads/2014/11/Bionik-400-EC-1000x1000--360x360.png)  \n**Bahan Aktif:** Dimetoate 400 g/l  \n**Deskripsi:** Insektisida racun kontak dan lambung berbentuk pekatan berwarna kekuning-kuningan yang dapat diemulsikan untuk mengendalikan hama perusak daun ( Plutella Xylostella, Crocidolomia Binotalis ) dan kutu daun ( Myzus Persicae ) pada tanaman kubis.  \n**Pengaplikasian:** Penyemprotan Volume tinggi  \n**Petunjuk Penggunaan:**  \n| Tanaman | Gulma Sasaran | Dosis Anjuran |\n| --- | --- | --- |\n| Kubis | Ulat Perusak Daun Plutella xylostella | 1 – 2 ml/l |\n| Kubis | Ulat Perusak Daun Crocidolomia binotalis | 1 – 2 ml/l |\n| Kubis | Kutu Daun Myzus persicae | 0.5 – 1.0 ml/l |  \n---'),
#  Document(metadata={'doc_type': 'product', 'product_name': 'DASATRIN 110 SC', 'group': 'insektisida'}, page_content='![Image of product: DASATRIN 110 SC](https://kresna.co.id/sarikresnakimia/wp-content/uploads/2014/11/Dasatrin-110-EC-1000x1000-360x360.png)  \n**Bahan Aktif:** Sipermetrin 110 g/l  \n**Deskripsi:** Insektisida racun kontak dan lambung berbentuk pekatan berbentuk pekatan berwarna kekuningan yang dapat diemulsikan untuk mengendalikan hama kutu daun dan ulat grayak pada bawang merah.  \n**Pengaplikasian:** Populasi atau intensitas serangan hama telah mencapai ambangnya setempat.  \n**Petunjuk Penggunaan:**  \n| Tanaman | Gulma Sasaran | Dosis Anjuran |\n| --- | --- | --- |\n| Bawang Merah | Kutu Daun Aphis glycines | 0.75 – 1.0 ml/l |\n| Bawang Merah | Ulat Grayak Spodoptera exigua | 1 ml/l |\n| Kakao | Penggerek Buah Conopomorpha cramerella | 0.5 – 1.0 ml/l |  \n---'),
#  Document(metadata={'doc_type': 'product', 'product_name': 'FASTOP 100 EC', 'group': 'insektisida'}, page_content='![Image of product: FASTOP 100 EC](https://kresna.co.id/sarikresnakimia/wp-content/uploads/2014/11/Fast-100-EC-1000x1000-360x360.png)  \n**Bahan Aktif:** Alfa-Sipermetrin100 g/l  \n**Deskripsi:** Insektisida racun kontak dan lambung berbentuk pekatan berwarna kekuningan yang dapat diemulsikan untuk mengendalikan ulat grayak dan hama thrips pada tanaman bawang merah.  \n**Pengaplikasian:** saat populasi atau intensitas serangan Hama telah mencapai ambang pengendaliannya sesuai rekomendasi setempat. Penyemprotan volume tinggi  \n**Petunjuk Penggunaan:**  \n| Tanaman | Gulma Sasaran | Dosis Anjuran |\n| --- | --- | --- |\n| Bawang Merah | Ulat Grayak Spodoptera exigua | 0.5 – 1.0 ml/l |\n| Bawang Merah | Trips Thrips tabaci | 0.75 – 1.0 ml/l |\n| Bawang Merah | Trips Thrips tabaci | 0.75 – 1.0 ml/l |\n| Bawang Merah | Trips Thrips tabaci | 0.75 – 1.0 ml/l |  \n---'),
#  Document(metadata={'doc_type': 'product', 'product_name': 'FAST 50 EC', 'group': 'insektisida'}, page_content='![Image of product: FAST 50 EC](https://kresna.co.id/sarikresnakimia/wp-content/uploads/2014/11/Fast-50-EC-1000x1000-min-360x360.png)  \n**Bahan Aktif:** Alfa-Sipermetrin 50 g/l  \n**Deskripsi:** Insektisida racun kontak dan lambung berbentuk pekatan yang dapat diemulsikan berwarna kekuningan untuk mengendalikan hama ulat grayak ( Spodoptera Litura ) pada tanaman kedelai.  \n**Pengaplikasian:** Penyemprotan volume tinggi  \n**Petunjuk Penggunaan:**  \n| Tanaman | Gulma Sasaran | Dosis Anjuran |\n| --- | --- | --- |\n| Kedelai | Ulat Grayak Spodoptera litura | 3 – 4 ml/l |\n| Kedelai | Ulat Grayak Spodoptera litura | 3 – 4 ml/l |  \n---'),
#  Document(metadata={'doc_type': 'product', 'product_name': 'FORTUNA 290 SL', 'group': 'insektisida'}, page_content='![Image of product: FORTUNA 290 SL](https://kresna.co.id/sarikresnakimia/wp-content/uploads/2014/11/Fortuna-290-SL-1000x1000-360x360.png)  \n**Bahan Aktif:** Dimehipo 290 g/l  \n**Deskripsi:** Insektisida racun kontak, lambung, dan sistemik berbentuk pekatan yang dapat larut dalam air, berwarna coklat kemerah – merahan untuk mengendalikan hama lalat bibit Atherigona exigua pada tanaman jagung.  \n**Pengaplikasian:** Penyemprotan volume tinggi dimulai pada waktu 6 hari setelah tanam. Waktu aplikasi untuk hama sasaran apabila populasi atau intensitas serangga hama sudah mencapai ambang pengendalian sesuai rekomendasi setempat.  \n**Petunjuk Penggunaan:**  \n| Tanaman | Gulma Sasaran | Dosis Anjuran |\n| --- | --- | --- |\n| Jagung | Lalat Bibit Atherigona sp. | 1,5 – 2 ml/l |\n| Jagung | Lalat Bibit Atherigona sp. | 1,5 – 2 ml/l |\n| Jagung | Lalat Bibit Atherigona sp. | 1,5 – 2 ml/l |\n| Jagung | Lalat Bibit Atherigona sp. | 1,5 – 2 ml/l |\n| Jagung | Lalat Bibit Atherigona sp. | 1,5 – 2 ml/l |\n| Jagung | Lalat Bibit Atherigona sp. | 1,5 – 2 ml/l |  \n---'),
#  Document(metadata={'doc_type': 'product', 'product_name': 'FOSTIN 610 EC', 'group': 'insektisida'}, page_content='![Image of product: FOSTIN 610 EC](https://kresna.co.id/sarikresnakimia/wp-content/uploads/2014/11/FOSTIN-1000x1000-min-360x360.png)  \n**Bahan Aktif:** Klorpirifos 550 g/l + Sipermetrin 60 g/l  \n**Deskripsi:** Insektisida racun kontak dan lambung berbentuk pekatan yang dapat diemulsikan untuk mengendalikan hama ulat grayak ( Spodoptera Litura ) pada tanaman kedelai.  \n**Pengaplikasian:** saat populasi atau intensitas serangan Hama telah mencapai ambang pengendaliannya sesuai rekomendasi setempat.  \n**Petunjuk Penggunaan:**  \n| Tanaman | Gulma Sasaran | Dosis Anjuran |\n| --- | --- | --- |\n| Kedelai | Ulat Grayak (Spodoptera litura) | 0.5 -1.0 ml/l |\n| Kedelai | Ulat Grayak (Spodoptera litura) | 0.5 -1.0 ml/l |\n| Kedelai | Ulat Grayak (Spodoptera litura) | 0.5 -1.0 ml/l |  \n---'),
#  Document(metadata={'doc_type': 'product', 'product_name': 'GEMAFUR 3 GR', 'group': 'insektisida'}, page_content='![Image of product: GEMAFUR 3 GR](https://kresna.co.id/sarikresnakimia/wp-content/uploads/2014/11/GEMAFURR-248x424.png)  \n**Bahan Aktif:** Karbofuran 3%  \n**Deskripsi:** Insektisida / Nematisida sistemik, berbentuk butiran warna ungu, untuk mengendalikan hama pada tanaman cabai, kedelai, padi, dan lain-lain.  \n**Pengaplikasian:** Penyemprotan volume tinggi  \n**Petunjuk Penggunaan:**  \n| Tanaman | Gulma Sasaran | Dosis Anjuran |\n| --- | --- | --- |\n| Kedelai | Lalat buah (Ophiomya phaseoli) | 15-20 kg/ha |\n| Kedelai | Lalat buah (Ophiomya phaseoli) | 15-20 kg/ha |\n| Padi Sawah | Wereng Coklat (Nilaparvata lugens) | 15-20 kg/ha |\n| Padi Sawah | Penggerek Batang (Scirpophaga incertulas) | 15-20 kg/ha |  \n---'),
#  Document(metadata={'doc_type': 'product', 'product_name': 'GEMILANG 110 EC', 'group': 'insektisida'}, page_content='![Image of product: GEMILANG 110 EC](https://kresna.co.id/sarikresnakimia/wp-content/uploads/2014/11/Gemilang-110-EC-1000x1000-360x360.png)  \n**Bahan Aktif:** Sipermetrin 110 g/l  \n**Deskripsi:** Insektisida racun kontak dan lambung berbentuk pekatan berwarna kekuningan yang dapat diemulsikan untuk mengendalikan hama kutu daun dan ulat grayak pada bawang merah.  \n**Pengaplikasian:** Populasi atau intensitas serangan hama telah mencapai ambang setempat  \n**Petunjuk Penggunaan:**  \n| Tanaman | Gulma Sasaran | Dosis Anjuran |\n| --- | --- | --- |\n| Cabai | Ulat Grayak (Spodoptera litura) | 0.5 -1.0 ml/l |\n| Cabai | Ulat Grayak (Spodoptera litura) | 0.5 -1.0 ml/l |  \n---'),
#  Document(metadata={'doc_type': 'product', 'product_name': 'GUNTUR 75 WP', 'group': 'insektisida'}, page_content='![Image of product: GUNTUR 75 WP](https://kresna.co.id/sarikresnakimia/wp-content/uploads/2014/11/Guntur-75-WP-1000x1000-360x360.png)  \n**Bahan Aktif:** Siromazin 75%  \n**Deskripsi:** Insektisida berbentuk tepung yang dapat disuspensikan dan berwarna putih. Bekerja sebagai Insect Growth Regulation ( IGR ) yang mengganggu proses ganti kulit hama sasaran. Dapat membentuk suspensi dalam air untuk mengendalikan hama ulat grayak ( Spodoptera Exigua ) pada tanaman bawang merah, hama pengorok daun ( Lyriomiza Huidobrensis ) dan kutu daun ( Myzus Persicae ) pada tanman kentang.  \n**Pengaplikasian:** Penyemprotan volume tinggi Apabila belum jelas hubungi petugas yang berwenang.  \n**Petunjuk Penggunaan:**  \n| Tanaman | Gulma Sasaran | Dosis Anjuran |\n| --- | --- | --- |\n| Bawang Merah | Ulat Grayak (Spodoptera exigua) | 0,45 – 0,6 kg/ha |\n| Kentang | Pengorok daun (Liriomyza huidobrensis) | 0,15 – 3 kg/ha |\n| Kentang | Kutu daun ( Myzus persicae ) | 0,3 – 0,6 Kg/ha |\n| Padi | Walang sangit Leptocorisa oratorius | PVT : 1.5 – 2 g/l |\n| Padi | Belalang Oxya sp. | PVT : 1 – 2 g/l |  \n---'),
#  Document(metadata={'doc_type': 'product', 'product_name': 'HALONA 200/50 EC', 'group': 'insektisida'}, page_content='![Image of product: HALONA 200/50 EC](https://kresna.co.id/sarikresnakimia/wp-content/uploads/2014/11/Halona-200-50-EC-1000x1000-360x360.png)  \n**Bahan Aktif:** Klorpirifos 200 + Sipemetrin 50  \n**Deskripsi:** Insektisida racun kontak dan lambung berbentuk pekatan yang dapat diemulsikan berwarna coklat kekuningan untuk mengendalikan penghisap buah ( Helopeltis Antonii ) dan penggerek buah ( Conopomorpha Cramerella ) pada tanaman kakao.  \n**Pengaplikasian:** Penyemprotan dilakukan segera setelah terlibat adanya serangan atau 7 hari setelah tanam  \n**Petunjuk Penggunaan:**  \n| Tanaman | Gulma Sasaran | Dosis Anjuran |\n| --- | --- | --- |\n| Kakao | Penghisap buah Helopeltis antonii | 0.5 – 1.0 ml/l |\n| Kakao | Penggerek Buah Conopomorpha cramerella | 0.5 – 1.0 ml/l |\n| Kakao | Penggerek Buah Conopomorpha cramerella | 0.5 – 1.0 ml/l |  \n---'),
#  Document(metadata={'doc_type': 'product', 'product_name': 'HOKY 30 EC', 'group': 'insektisida'}, page_content='![Image of product: HOKY 30 EC](https://kresna.co.id/sarikresnakimia/wp-content/uploads/2014/11/Hoky-30-EC-1000x1000-360x360.png)  \n**Bahan Aktif:** Sipermetrin 30 g/l  \n**Deskripsi:** Insektisida racun kontak dan lambung berbentuk pekatan yang dapat diemulsikan untuk mengendalikan ulat grayak ( Spodoptera Litura ) pada tanaman cabai dan kedelai.  \n**Pengaplikasian:** Penyemprotan Volume tinggi Penyemprotan Volume tinggi  \n**Petunjuk Penggunaan:**  \n| Tanaman | Gulma Sasaran | Dosis Anjuran |\n| --- | --- | --- |\n| Cabai | Ulat Grayak (Spodoptera litura) | 1.0 – 2.0 ml/l |\n| Cabai | Ulat Grayak (Spodoptera litura) | 1.0 – 2.0 ml/l |\n| Kedelai | Ulat Grayak (Spodoptera litura) | 1.0 – 2.0 ml/l |  \n---'),
#  Document(metadata={'doc_type': 'product', 'product_name': 'IMIDAPLUS 200 SL', 'group': 'insektisida'}, page_content='![Image of product: IMIDAPLUS 200 SL](https://kresna.co.id/sarikresnakimia/wp-content/uploads/2014/10/IMIDAPLUS-200-360x360.png)  \n**Bahan Aktif:** Imidakloprid 200 g/l  \n**Deskripsi:** Insektisida racun kontak, lambung, dan sistemik berbentuk larutan dalam air berwarna coklat kemerah – merahan untuk mengendalikan hama – hama pada pertanaman kedelai.  \n**Pengaplikasian:** Penyemprotan volume tinggi dimulai pada waktu 6 hari setelah tanam.  \n**Petunjuk Penggunaan:**  \n| Tanaman | Gulma Sasaran | Dosis Anjuran |\n| --- | --- | --- |\n| Kedelai | Penghisap polong Nezara viridula | 1 ml/l |\n| Kedelai | Penggulung daun Lamprosema indicata | 0.5 – 1 ml/l |\n| Kedelai | Ulat Jengkal Chrysodexis calcites | 0.5 – 1 ml/l |\n| Kedelai | Ulat Grayak Spodoptera litura | 0.5 – 1 ml/l |\n| Kedelai | Penghisap Daun Empoasca sp. | 0.5 – 1 ml/l |\n| Kedelai | Penggerek Daun Etiella zinckenella | 0.5 – 1 ml/l |\n| Kedelai | Penggerek Daun Etiella zinckenella | 0.5 – 1 ml/l |\n| Cabai | Kutu Daun Myzus persicae | 1 – 1.5 ml/l |\n| Cabai | Trips Thrips tabaci | 1 – 1.5 ml/l |  \n---'),
#  Document(metadata={'doc_type': 'product', 'product_name': 'IMIDAPLUS 25 WP', 'group': 'insektisida'}, page_content='![Image of product: IMIDAPLUS 25 WP](https://kresna.co.id/sarikresnakimia/wp-content/uploads/2014/11/Imidaplus-25-WP-1000x1000-360x360.png)  \n**Bahan Aktif:** Imidakloprid 25 %  \n**Deskripsi:** Insektisida racun kontak, lambung bersifat sistemik berbentuk tepung yang dapat disuspensikan untuk mengendalikan hama wereng coklat ( Nilaparvata Lugens ) pada tanaman padi sawah.  \n**Pengaplikasian:** Penyemprotan volume tinggi  \n**Petunjuk Penggunaan:**  \n| Tanaman | Gulma Sasaran | Dosis Anjuran |\n| --- | --- | --- |\n| Padi | Wereng Coklat Nilaparvata lugens | 1.5 – 2.0 g/l |  \n---'),
#  Document(metadata={'doc_type': 'product', 'product_name': 'ISADORA 75 SP', 'group': 'insektisida'}, page_content='![Image of product: ISADORA 75 SP](https://kresna.co.id/sarikresnakimia/wp-content/uploads/2014/11/Isadora-75-SP-1000x1000-360x360.png)  \n**Bahan Aktif:** Asefat 75 %  \n**Deskripsi:** Insektisida sistemik berbentuk tepung berwarna putih yang dapat dilarutkan dalam air untuk mengendalikan hama ulat daun ( Plutella Xylostella ) dan ulat krop ( Crocidolomia Pavonana ) pada tanaman kubis.  \n**Pengaplikasian:** Saat terlihat mulai adanya gejala serangan Penyemprotan volume tinggi apabila populasi atau intensitas serangan hama telah mencapai ambang pengendalian sesuai rekomendasi setempat  \n**Petunjuk Penggunaan:**  \n| Tanaman | Gulma Sasaran | Dosis Anjuran |\n| --- | --- | --- |\n| Kubis | Ulat Daun Plutella xylostella | 1 – 2 g/l |\n| Kubis | Ulat Crop Crocidolomia pavonana | 1 – 2 g/l |\n| Kubis | Ulat Crop Crocidolomia pavonana | 1 – 2 g/l |\n| Kubis | Ulat Crop Crocidolomia pavonana | 1 – 2 g/l |\n| Kubis | Ulat Crop Crocidolomia pavonana | 1 – 2 g/l |  \n---'),
#  Document(metadata={'doc_type': 'product', 'product_name': 'KARATE 50 EC', 'group': 'insektisida'}, page_content='![Image of product: KARATE 50 EC](https://kresna.co.id/sarikresnakimia/wp-content/uploads/2014/11/Karate-50-SC-1000x1000-360x360.png)  \n**Bahan Aktif:** Permetrin 50 g/l  \n**Deskripsi:** Insektisida racun kontak dan perut berbentuk pekatan yang dapat diemulsikan berwarna kuning muda untuk mengendalikan hama ulat grayak ( SpodopteraLitura ) pada tanaman cabai.  \n**Pengaplikasian:** Penyemprotan volume tinggi  \n**Petunjuk Penggunaan:**  \n| Tanaman | Gulma Sasaran | Dosis Anjuran |\n| --- | --- | --- |\n| Cabai | Ulat Grayak Spodoptera litura | 0.5 – 1.0 ml/l |  \n---'),
#  Document(metadata={'doc_type': 'product', 'product_name': 'KARDAN 4 GR', 'group': 'insektisida'}, page_content='![Image of product: KARDAN 4 GR](https://kresna.co.id/sarikresnakimia/wp-content/uploads/2014/11/Kardan-4-GR-1000x10001-360x360.png)  \n**Bahan Aktif:** Kartap Hidroklorida 4%  \n**Deskripsi:** Insektisida sistemik racun kontak dan lambung berbentuk butiran berwarna ungu kemerahan untuk mengendalikan lalat bibit ( Agromyza sp. ) pada tanaman kedelai.  \n**Pengaplikasian:** Penabur pada tanah  \n**Petunjuk Penggunaan:**  \n| Tanaman | Gulma Sasaran | Dosis Anjuran |\n| --- | --- | --- |\n| Kedelai | Lalat Bibit Agromyza sp. | 10 -15 kg/ha |\n| Padi | Wereng Coklat Nilaparvata lugens | 9 – 12 kg/ha |\n| Padi | Penggerek batang Scirpophaga incertulas | 9 – 12 kg/ha |\n| Tebu | Hama Uret Lepidiota stigma | 40 kg/ha |  \n---'),
#  Document(metadata={'doc_type': 'product', 'product_name': 'KARDAN 50 SP', 'group': 'insektisida'}, page_content='![Image of product: KARDAN 50 SP](https://kresna.co.id/sarikresnakimia/wp-content/uploads/2014/11/Kardan-50-SP-1000x1000-360x360.png)  \n**Bahan Aktif:** Kartap Hidroklorida 50%  \n**Deskripsi:** Insektisida sistemik racun kontak berbentuk tepung berwarna hijau muda yang dapat dilarutkan dalam air untuk mengendalikan hama pada tanaman teh, kentang, dan cabai.  \n**Pengaplikasian:** Penyemprotan volume tinggi  \n**Petunjuk Penggunaan:**  \n| Tanaman | Gulma Sasaran | Dosis Anjuran |\n| --- | --- | --- |\n| The | Penghisap daun Helopeltis sp. | 0.5 – 1.0 kg/ha |\n| Kentang | Pengorok daun (Liriomyza huidobrensis) | 2 – 4 g/l |\n| Kentang | Trips Thrips palmi | 4 – 8 g/l |\n| Cabai | Ulat grayak Spodoptera litura | 2 – 4 g/l |  \n---'),
#  Document(metadata={'doc_type': 'product', 'product_name': 'KEJORA 15 EC', 'group': 'insektisida'}, page_content='![Image of product: KEJORA 15 EC](https://kresna.co.id/sarikresnakimia/wp-content/uploads/2014/11/KEJORA-15-EC-1000x1000-360x360.png)  \n**Bahan Aktif:** Alfa-sipermetrin 15 g/l  \n**Deskripsi:** Insektisida racun kontak dan lambung berbentuk pekatan berwarna kuning yang dapat membentuk emulsi dalam air untuk mengendalikan ulat grayak ( Spodoptera Litura F. ) pada tanaman kedelai.  \n**Pengaplikasian:**  \n**Petunjuk Penggunaan:**  \n| Tanaman | Gulma Sasaran | Dosis Anjuran |\n| --- | --- | --- |\n| Kedelai | Ulat grayak Spodoptera litura | 0.25 – 0.5 ml/l |  \n---'),
#  Document(metadata={'doc_type': 'product', 'product_name': 'KILIRI 20 EC', 'group': 'insektisida'}, page_content='![Image of product: KILIRI 20 EC](https://kresna.co.id/sarikresnakimia/wp-content/uploads/2021/02/kiliri-360x360.png)  \n**Bahan Aktif:** Abamektin 20 g/l  \n**Deskripsi:** Insektisida racun kontak dan lambung berbentuk pekatan berwarna kuning muda yang dapat di emulsikan ke dalam air untuk mengendalikan hama penggerek daun( Liriomyza huidobrensis) pada tanaman kentang dan hama thrips Thirps parvispinus dan kutu daun Myzus persicae pada tanaman Cabai merah.  \n**Pengaplikasian:** saat populasi atau intensitas serangan Hama telah mencapai ambang pengendaliannya sesuai rekomendasi setempat.  \n**Petunjuk Penggunaan:**  \n| Tanaman | Gulma Sasaran | Dosis Anjuran |\n| --- | --- | --- |\n| Kentang | Pengorok daun Liriomyza huidobrensis | 0.25 – 0.5 ml/l |\n| Kentang | Pengorok daun Liriomyza huidobrensis | 0.25 – 0.5 ml/l |\n| cabai | Trips Thrips parvispinus | 0.25 – 0.5 ml/l |\n| cabai | Kutu Daun Myzus persicae | 0,375 – 0,500 ml/l |  \n---'),
#  Document(metadata={'doc_type': 'product', 'product_name': 'KRESBAN 200 EC', 'group': 'insektisida'}, page_content='![Image of product: KRESBAN 200 EC](https://kresna.co.id/sarikresnakimia/wp-content/uploads/2014/11/Kresban-200-EC-1000x1000-360x360.png)  \n**Bahan Aktif:** Klorpyrifos 200 g/l  \n**Deskripsi:** Insektisida racun kontak dan lambung berbentuk pekatan yang dapat diemulsikan berwarna kekuningan untuk mengendalikan ulat grayak Spodoptera exigua pada tanaman bawang merah.  \n**Pengaplikasian:** saat populasi atau intensitas serangan Hama telah mencapai ambang pengendaliannya sesuai rekomendasi setempat.  \n**Petunjuk Penggunaan:**  \n| Tanaman | Gulma Sasaran | Dosis Anjuran |\n| --- | --- | --- |\n| Kentang | Pengorok daun Liriomyza huidobrensis | 0.25 – 0.5 ml/l |\n| Kentang | Pengorok daun Liriomyza huidobrensis | 0.25 – 0.5 ml/l |\n| cabai | Trips Thrips parvispinus | 0.25 – 0.5 ml/l |\n| cabai | Kutu Daun Myzus persicae | 0,375 – 0,500 ml/l |  \n---'),
#  Document(metadata={'doc_type': 'product', 'product_name': 'KRESNADAN 3 GR', 'group': 'insektisida'}, page_content='![Image of product: KRESNADAN 3 GR](https://kresna.co.id/sarikresnakimia/wp-content/uploads/2014/10/KRESNADAN-360x360.png)  \n**Bahan Aktif:** Karbofuran 3%  \n**Deskripsi:** Insektida racun kontak, lambung dan sistemik berbantuk butiran berwarna jingga untuk mengendalikan hama-hama pada tanaman dan padi sawah.  \n**Pengaplikasian:** Penyemprotan volume tinggi  \n**Petunjuk Penggunaan:**  \n| Tanaman | Gulma Sasaran | Dosis Anjuran |\n| --- | --- | --- |\n| Padi sawah | Wereng Coklat Nilaparvata lugens | 15 – 20 kg/ha |\n| Padi sawah | Penggerek batang Scirpophaga incertulas | 15 – 20 kg/ha |  \n---'),
#  Document(metadata={'doc_type': 'product', 'product_name': 'LAMDARIN 55 EC', 'group': 'insektisida'}, page_content='![Image of product: LAMDARIN 55 EC](https://kresna.co.id/sarikresnakimia/wp-content/uploads/2014/11/Lamdarin-55-EC-1000x1000-360x360.png)  \n**Bahan Aktif:** Lamda sihalotrin 55 g/l  \n**Deskripsi:** Insektisida racun kontak dan lambung berbentuk pekatan berwarna kuning yang dapat diemulsikan untuk mengendalikan hama-hama pada tanaman jagung, kakao dan kedelai.  \n**Pengaplikasian:** Penyemprotan volume tinggi  \n**Petunjuk Penggunaan:**  \n| Tanaman | Gulma Sasaran | Dosis Anjuran |\n| --- | --- | --- |\n| Kakao | Penghisap buah Helopeltis antonii | 0.25 – 0.5 ml/l |\n| Kedelai | Perusak daun Lamprosema indicata | 0.125 – 0.25 ml/l |\n| Kedelai | Penghisap polong Riptortus linearis | 0.125 – 0.25 ml/l |\n| Kedelai | Penggerek Polong Etiella zinckenella | 0.125 – 0.25 ml/l |\n| Jagung | Penggerek batang Ostrinia furnacalis | PVT : 2-3 ml/l |\n| Penggerek tongkol Helicoverpa armigera | Penggerek batang Ostrinia furnacalis | PVT : 2-3 ml/l |  \n---'),
#  Document(metadata={'doc_type': 'product', 'product_name': 'LASER 300 EC', 'group': 'insektisida'}, page_content='![Image of product: LASER 300 EC](https://kresna.co.id/sarikresnakimia/wp-content/uploads/2014/11/Laser-300-EC-1000x1000-360x360.png)  \n**Bahan Aktif:** Permethryn 300 g/l  \n**Deskripsi:** Insektisida racun kontak dan lambung berbentuk pekatan yang dapat diemulsikan berwarna kuning muda untuk mengendalikan hama pada tanaman kentang.  \n**Pengaplikasian:** Penyemprotan volume tinggi dimulai setelah ditemukan populasi hama atau gejala serangan  \n**Petunjuk Penggunaan:**  \n| Tanaman | Gulma Sasaran | Dosis Anjuran |\n| --- | --- | --- |\n| Kentang | Hama trips Thrips parvisipinus | 0,75 – 1 ml/l |\n| Kentang | Hama trips Thrips parvisipinus | 0,75 – 1 ml/l |\n| Kentang | Kutu daun Myzuz persicae | 0,75 – 1 ml/l |\n| Kentang | Kutu daun Myzuz persicae | 0,75 – 1 ml/l |  \n---'),
#  Document(metadata={'doc_type': 'product', 'product_name': 'MATARIN 50 EC', 'group': 'insektisida'}, page_content='![Image of product: MATARIN 50 EC](https://kresna.co.id/sarikresnakimia/wp-content/uploads/2014/11/Matarin-50-EC-1000x1000-360x360.png)  \n**Bahan Aktif:** Lamda sihalotrin 50 g/l  \n**Deskripsi:** Insektisida racun kontak dan lambung berbentuk pekatan yang dapat di emulsikan dalam air, berwarna kuning-kekuningan untuk mengendalikan hama pada tanaman cabai, bawang, kelapa sawit dan kakao.  \n**Pengaplikasian:** Penyemprotan volume tinggi dimulai setelah ditemukan populasi hama atau gejala serangan  \n**Petunjuk Penggunaan:**  \n| Tanaman | Gulma Sasaran | Dosis Anjuran |\n| --- | --- | --- |\n| kakao | Penggerek Buah Conopomorpha cramerella | 1.5 – 2.0 ml/l |\n| kakao | Penghisap buah Helopeltis antonii | 1.5 – 2.0 ml/l |\n| Bawang Merah | Ulat Grayak Spodoptera exigua | 0.25 – 0.5 ml/l |\n| Cabai | Kutu daun ( Myzus persicae ) | 0.25 – 0.5 ml/l |\n| Cabai | Trips Thrips parvispinus | 0.25 – 0.5 ml/l |\n| Kelapa Sawit | Ulat Api Setora nitens | 0.25 – 0.5 ml/l |  \n---'),
#  Document(metadata={'doc_type': 'product', 'product_name': 'OKRITE 20 EC', 'group': 'insektisida'}, page_content='![Image of product: OKRITE 20 EC](https://kresna.co.id/sarikresnakimia/wp-content/uploads/2014/11/Okrite-20-EC-1000x1000-360x360.png)  \n**Bahan Aktif:** Abamectin 20 g/l  \n**Deskripsi:** Insektisida racun kontak dan lambung berbentuk pekatan berwarna kuning muda yang dapat membentuk emulsi dalam air untuk mengendalikan hama kutu daun ( Myzus Persicaedan ), hama thrips ( Thrips Parvispinus ) pada tanaman cabai.  \n**Pengaplikasian:** Penyemprotan volume tinggi  \n**Petunjuk Penggunaan:**  \n| Tanaman | Gulma Sasaran | Dosis Anjuran |\n| --- | --- | --- |\n| Cabai | Kutu Daun Myzus persicae | 0.25 -0.5 ml/l |\n| Cabai | Trips Thrips parvispinus | 0.25 -0.5 ml/l |  \n---'),
#  Document(metadata={'doc_type': 'product', 'product_name': 'QIUMEX 36 EC', 'group': 'insektisida'}, page_content='![Image of product: QIUMEX 36 EC](https://kresna.co.id/sarikresnakimia/wp-content/uploads/2014/11/Qiumex-36-EC-1000x1000-360x360.png)  \n**Bahan Aktif:** Abamectin 36 g/l  \n**Deskripsi:** Insektsida racun kontak dan lambung berbentuk pekatan yang dapat diemulsikan untuk mengendalikan hama pada tanaman.  \n**Pengaplikasian:** Penyemprotan volume tinggi  \n**Petunjuk Penggunaan:**  \n| Tanaman | Gulma Sasaran | Dosis Anjuran |\n| --- | --- | --- |\n| Bawang Merah | Pengorok daun (Liriomyza huidobrensis) | 0.25 – 0.5 ml/l |  \n---'),
#  Document(metadata={'doc_type': 'product', 'product_name': 'SERGAP 410 EC', 'group': 'insektisida'}, page_content='![Image of product: SERGAP 410 EC](https://kresna.co.id/sarikresnakimia/wp-content/uploads/2014/11/Sergap-410-EC-1000x1000-360x360.png)  \n**Bahan Aktif:** Klorpyrifos 410 g/l  \n**Deskripsi:** Insektisida racun kontak dan lambung berbentuk pekatan yang dapat diemulsikan berwarna kekuning–kuningan untuk mengendalikan ulat grayak ( Spodoptera Exigua ) dan kutu daun ( Aphis Sp. ) pada tanaman bawang merah.  \n**Pengaplikasian:** Penyemprotan volume tinggi  \n**Petunjuk Penggunaan:**  \n| Tanaman | Gulma Sasaran | Dosis Anjuran |\n| --- | --- | --- |\n| Bawang Merah | Ulat Grayak Spodoptera exigua | 1.5 – 2.0 ml/l |\n| Bawang Merah | Kutu daun Aphis sp. | 1.5 – 2.0 ml/l |  \n---'),
#  Document(metadata={'doc_type': 'product', 'product_name': 'TAMABAS 500 EC', 'group': 'insektisida'}, page_content='![Image of product: TAMABAS 500 EC](https://kresna.co.id/sarikresnakimia/wp-content/uploads/2014/11/Tamabas-500-EC-1000x1000-360x360.png)  \n**Bahan Aktif:** BPMC 500 g/l  \n**Deskripsi:** Insektisida racun kontak dan lambung berbentuk pekatan berwarna kekuning – kuningan yang dapat diemulsikan untuk mengendalikan hama ulat grayak pada tanaman cabai.  \n**Pengaplikasian:** Penyemprotan volume tinggi  \n**Petunjuk Penggunaan:**  \n| Tanaman | Gulma Sasaran | Dosis Anjuran |\n| --- | --- | --- |\n| Cabai | Ulat grayak Spodoptera litura | 3 ml/l |\n| Padi sawah | Belalang Oxya sp. | PVT: 2 ml/l |\n| Padi sawah | Wereng coklat Nilaparvata lugens | 0.5 – 1 l/ha |  \n---'),
#  Document(metadata={'doc_type': 'product', 'product_name': 'TAMACIN 50 WP', 'group': 'insektisida'}, page_content='![Image of product: TAMACIN 50 WP](https://kresna.co.id/sarikresnakimia/wp-content/uploads/2014/11/Tamacin-50-WP-1000x1000-360x360.png)  \n**Bahan Aktif:** MIPC 51,3 %  \n**Deskripsi:** Insektisida racun kontak berbentuk tepung berwarna putih yang dapat disuspensikan digunakan untuk mengendalikan hama wereng coklat dan ulat grayak pada tanaman padi, cabai, dan kedelai.  \n**Pengaplikasian:** Penyemprotan volume tinggi  \n**Petunjuk Penggunaan:**  \n| Tanaman | Gulma Sasaran | Dosis Anjuran |\n| --- | --- | --- |\n| Cabai | Ulat grayak Spodoptera litura | 1 – 2 ml/l |\n| Kedelai | Ulat grayak Spodoptera litura | 1 – 2 ml/l |\n| Padi | Wereng Coklat Nilaparvata lugens | 2 – 4 ml/l |  \n---'),
#  Document(metadata={'doc_type': 'product', 'product_name': 'TAMACRON 500 EC', 'group': 'insektisida'}, page_content='![Image of product: TAMACRON 500 EC](https://kresna.co.id/sarikresnakimia/wp-content/uploads/2014/11/Tamacron-500-EC-1000x1000-360x360.png)  \n**Bahan Aktif:** Profenofos 500 g/l  \n**Deskripsi:** Insektisida racun kontak dan perut berbentuk pekatan yang dapat diemulsikan berwarna kuning kecoklatan untuk mengendalikan hama kutu daun ( Myzus Percisae ) dan Thrips ( Thrips Parvispinus ) pada tanaman cabai.  \n**Pengaplikasian:** Penyemprotan volume tinggi  \n**Petunjuk Penggunaan:**  \n| Tanaman | Gulma Sasaran | Dosis Anjuran |\n| --- | --- | --- |\n| Cabai | Kutu Daun Myzus persicae | 2 ml/l |\n| Cabai | Trips Thrips parvispinus | 0.5 – 1 ml/l |  \n---'),
#  Document(metadata={'doc_type': 'product', 'product_name': 'TAMAFUR 3 GR', 'group': 'insektisida'}, page_content='![Image of product: TAMAFUR 3 GR](https://kresna.co.id/sarikresnakimia/wp-content/uploads/2014/11/Tamafur-3-GR-1000x1000-360x360.png)  \n**Bahan Aktif:** Karbofuran 3%  \n**Deskripsi:** Insektisida / Nematisida sistemik, berbentuk butiran warna ungu, untuk mengendalikan hama – hama pada tanaman cabai, kedelai, padi, dan lain-lain.  \n**Pengaplikasian:** Penyemprotan volume tinggi  \n**Petunjuk Penggunaan:**  \n| Tanaman | Gulma Sasaran | Dosis Anjuran |\n| --- | --- | --- |\n| Cabai | Ulat grayak Spodoptera litura | 8.5 – 17 kg/ha |\n| Kedelai | Ulat grayak Spodoptera litura | 8.5 – 17 kg/ha |\n| Padi | Penggerek batang Scirpophaga innotata | 4.25 – 17 kg/ha |\n| Wereng Coklat Nilaparvata lugens | 17 kg/ha | 4.25 – 17 kg/ha |\n| Hama Ganjur Orseolia oryzae | 17 kg/ha | 4.25 – 17 kg/ha |  \n---'),
#  Document(metadata={'doc_type': 'product', 'product_name': 'TOPNIL 50 SC', 'group': 'insektisida'}, page_content='![Image of product: TOPNIL 50 SC](https://kresna.co.id/sarikresnakimia/wp-content/uploads/2014/11/Topnil-50-SC-1000x1000-360x360.png)  \n**Bahan Aktif:** Fipronil 50 g/l  \n**Deskripsi:** Insektisida sistemik berbentuk pekatan suspensi berwarna putih berdaya racun kontak dan lambung untuk mengendalikan hama pada tanaman padi sawah.  \n**Pengaplikasian:** Penyemprotan volume tinggi  \n**Petunjuk Penggunaan:**  \n| Tanaman | Gulma Sasaran | Dosis Anjuran |\n| --- | --- | --- |\n| Padi sawah | Wereng Coklat Nilaparvata lugens | 0.5 – 1.0 ml/l |\n| Padi sawah | Penggerek batang Scirpophaga innotata | 0.5 – 1.0 ml/l |  \n---'),
#  Document(metadata={'doc_type': 'product', 'product_name': 'TRESNA 25 EC', 'group': 'insektisida'}, page_content='![Image of product: TRESNA 25 EC](https://kresna.co.id/sarikresnakimia/wp-content/uploads/2014/11/Tresna-25-EC-1000x1000-360x360.png)  \n**Bahan Aktif:** Deltametrin 25 g/l  \n**Deskripsi:** Insektisida racun kontak dan lambung, berbentuk pekatan berwarna kekuning-kuningan yang dapat membentuk emulsi dalam air untuk mengendalikan hama pada tanaman bawang merah, cabai, jagung, kapas, kedelai, dan teh.  \n**Pengaplikasian:** Saat terlihat mulai adanya gejala serangan Penyemprotan volume tinggi apabila populasi atau intensitas serangan hama telah mencapai ambang pengendalian sesuai rekomendasi setempat  \n**Petunjuk Penggunaan:**  \n| Tanaman | Gulma Sasaran | Dosis Anjuran |\n| --- | --- | --- |\n| Bawang merah | Ulat grayak Spodoptera exigua | 1,2 – 2,4 l/ha |\n| Cabai | Ulat grayak Spodoptera sp. | 2,4 – 4,8 ml/l |\n| Jagung | Lalat bibit Atheriigona exigua | 1,2 – 2,4 l/ha |\n| Kapas | Penggerek buah Helicoverpa armigera | 0,6 – 1,2 l/ha |\n| Kedelai | Ulat grayak Spodoptera litura | 2,4 – 4,8 ml/l |\n| The | Penghisap daun Helopeltis antonii | 0,6 – 1,2 l/ha |\n| Semangka | Hama Trips Thrips sp. | 0,6 – 1,2 l/ha |\n| Semangka | Kutu daun Aphis sp. | 0,6 – 1,2 l/ha |\n| Tembakau | Ulat grayak Spodoptera sp. | 0,6 – 1,2 l/ha |\n| Tembakau | Penggerek pucuk Heliothis sp. | 0,6 – 1,2 l/ha |\n| Kelapa sawit | Ulat Api Setora nitens | 0,6 – 1,2 l/ha |  \n---'),
#  Document(metadata={'doc_type': 'product', 'product_name': 'VALERA 100 EC', 'group': 'insektisida'}, page_content='![Image of product: VALERA 100 EC](https://kresna.co.id/sarikresnakimia/wp-content/uploads/2014/11/Valera-200-EC-1000x1000-360x360.png)  \n**Bahan Aktif:** Fenvalerat 200 g/l  \n**Deskripsi:** Insektisida racun kontak dan lambung, berbentuk pekatan berwarna kuning muda yang dapat membentuk emulsi dalam air untuk mengendalikan ulat grayak ( Spodoptera Litura F. ) pada tanaman jeruk.  \n**Pengaplikasian:** Penyemprotan volume tinggi  \n**Petunjuk Penggunaan:**  \n| Tanaman | Gulma Sasaran | Dosis Anjuran |\n| --- | --- | --- |\n| Jeruk | Kutu daun Aphis sp. | 0.5 ml/l |  \n---'),
#  Document(metadata={'doc_type': 'product', 'product_name': 'VENUS 400 SL', 'group': 'insektisida'}, page_content='![Image of product: VENUS 400 SL](https://kresna.co.id/sarikresnakimia/wp-content/uploads/2014/11/Venus-400-SL-1000x1000-360x360.png)  \n**Bahan Aktif:** Dimehypo 400 g/l  \n**Deskripsi:** Insektisida racun kontak, lambung, dan sistemik berbentuk pekatan yang dapat larut dalam air, berwarna coklat kemerah-merahan untuk mengendalikan hama penggerek polong ( Etiella Zinckenella ), penggulung daun ( Lamprosema Indicata ), dan penghisap polong ( Nezara Viridula ) pada tanaman kedelai.  \n**Pengaplikasian:** Penyemprotan volume tinggi  \n**Petunjuk Penggunaan:**  \n| Tanaman | Gulma Sasaran | Dosis Anjuran |\n| --- | --- | --- |\n| Kedelai | Penggerek polong Etiella zinckenella | 0.75 ml/l |\n| Kedelai | Penggulung daun Lamprosema indicata | 0.75 ml/l |\n| Kedelai | Penghisap polong Nezara viridula | 0.75 ml/l |  \n---'),
#  Document(metadata={'doc_type': 'product', 'product_name': 'VIGOR 100 EC', 'group': 'insektisida'}, page_content='![Image of product: VIGOR 100 EC](https://kresna.co.id/sarikresnakimia/wp-content/uploads/2014/11/Vigor-100-EC-1000x1000-360x360.png)  \n**Bahan Aktif:** Sipermethryn 100 g/l  \n**Deskripsi:** Insektisida racun kontak dan lambung berbentuk pekatan berwarna kekuningan yang dapat diemulsikan untuk mengendalikan hama penghisap buah pada tanaman kakao.  \n**Pengaplikasian:** Penyemprotan volume tinggi  \n**Petunjuk Penggunaan:**  \n| Tanaman | Gulma Sasaran | Dosis Anjuran |\n| --- | --- | --- |\n| Kakao | Penghisap Buah Helopeltis antonii | 2 ml/l |\n| Kakao | Ulat kilan Hyposidra talaca | 0.5-1 ml/l |\n| Kakao | Penggerek buah Conopomorpha cramerella | 0.5-1 ml/l |  \n---'),
#  Document(metadata={'doc_type': 'product', 'product_name': 'VISTA 400 SL', 'group': 'insektisida'}, page_content='![Image of product: VISTA 400 SL](https://kresna.co.id/sarikresnakimia/wp-content/uploads/2014/11/Vista-400-SL-1000x1000-360x360.png)  \n**Bahan Aktif:** Dimehypo 400 g/l  \n**Deskripsi:** Insektisida racun kontak dan lambung berbentuk pekatan yang dapat larut dalam air, berwarna coklat kemerah-merahan untuk mengendalikan hama penggerek batang ( Tryporiza Incertulas ), wereng coklat ( Nilaprvata Lugens ) dan hama putih palsu ( Cnaphalocrosis Medinalis ) pada tanaman padi, dan hama ( Sexava Nubila ) pada tanaman kelapa.  \n**Pengaplikasian:** Penyemprotan volume tinggi  \n**Petunjuk Penggunaan:**  \n| Tanaman | Gulma Sasaran | Dosis Anjuran |\n| --- | --- | --- |\n| Padi | Penggerek Batang Scirpophaga incertulas | 2.25 -3.0 ml/l |\n| Padi | Wereng Coklat Nilaparvata lugens | 0.75 – 1.5 ml/l |\n| Padi | Hama putih palsu Cnaphalocrosis medinalis | 1.5 -3.0 ml/l |\n| Kelapa | Belalang Sexava nubila | 20 ml/pohon |')]

# %%
vector_store = SupabaseVectorStore.from_documents(
    all_docs,
    embeddings,
    client=supabase,
    table_name="documents",
    query_name="match_documents",
)

# %%
vector_store = SupabaseVectorStore(
    client=supabase,
    embedding=embeddings,
    table_name="documents",
    query_name="match_documents",
)

# %%
from tqdm.auto import tqdm

table_name = "documents"

# Delete all rows from the table if it exists
try:
    result = supabase.table(table_name).delete().gte('id', '').execute()
    print(f"Cleared existing data from {table_name}")
except Exception as e:
    print(f"Table {table_name} might not exist yet: {e}")

# Create Supabase vector store
batch_size = 10  # Start small, increase if it works
vector_store = None

batches = list(range(0, len(all_docs), batch_size))
for i in tqdm(batches, desc="Processing document batches"):
    batch = all_docs[i:i+batch_size]
    batch_num = i//batch_size + 1
    doc_range = f"{i+1} to {min(i+batch_size, len(all_docs))}"
    
    try:
        if vector_store is None:
            # Create the vector store with first batch
            vector_store = SupabaseVectorStore.from_documents(
                batch,
                embeddings,
                client=supabase,
                table_name="documents",
                query_name="match_documents",
            )
        else:
            # Add subsequent batches
            vector_store.add_documents(batch)
        
    except Exception as e:
        tqdm.write(f"✗ Batch {batch_num} error: {e}")
        continue

print("✓ All documents processed!")
# Out:
# Table documents might not exist yet: {'message': 'invalid input syntax for type uuid: ""', 'code': '22P02', 'hint': None, 'details': None}
# Processing batch 1: documents 1 to 10
# ✓ Batch completed successfully
# Processing batch 2: documents 11 to 20
# ✓ Batch completed successfully
# Processing batch 3: documents 21 to 30
# ✓ Batch completed successfully
# Processing batch 4: documents 31 to 40
# ✓ Batch completed successfully
# Processing batch 5: documents 41 to 50
# ✓ Batch completed successfully
# Processing batch 6: documents 51 to 60
# ✓ Batch completed successfully
# Processing batch 7: documents 61 to 70
# ✓ Batch completed successfully
# Processing batch 8: documents 71 to 80
# ✓ Batch completed successfully
# Processing batch 9: documents 81 to 90
# ✓ Batch completed successfully
# Processing batch 10: documents 91 to 100
# ✓ Batch completed successfully
# Processing batch 11: documents 101 to 110
# ✓ Batch completed successfully
# Processing batch 12: documents 111 to 120
# ✓ Batch completed successfully
# Processing batch 13: documents 121 to 130
# ✓ Batch completed successfully
# Processing batch 14: documents 131 to 140
# ✓ Batch completed successfully
# Processing batch 15: documents 141 to 150
# ✓ Batch completed successfully
# Processing batch 16: documents 151 to 160
# ✓ Batch completed successfully
# Processing batch 17: documents 161 to 170
# ✓ Batch completed successfully
# Processing batch 18: documents 171 to 180
# ✓ Batch completed successfully
# Processing batch 19: documents 181 to 190
# ✓ Batch completed successfully
# Processing batch 20: documents 191 to 200
# ✓ Batch completed successfully
# Processing batch 21: documents 201 to 210
# ✓ Batch completed successfully
# Processing batch 22: documents 211 to 220
# ✓ Batch completed successfully
# Processing batch 23: documents 221 to 230
# ✓ Batch completed successfully
# Processing batch 24: documents 231 to 240
# ✓ Batch completed successfully
# Processing batch 25: documents 241 to 250
# ✓ Batch completed successfully
# Processing batch 26: documents 251 to 260
# ✓ Batch completed successfully
# Processing batch 27: documents 261 to 270
# ✓ Batch completed successfully
# Processing batch 28: documents 271 to 280
# ✓ Batch completed successfully
# Processing batch 29: documents 281 to 290
# ✓ Batch completed successfully
# Processing batch 30: documents 291 to 300
# ✓ Batch completed successfully
# Processing batch 31: documents 301 to 310
# ✓ Batch completed successfully
# Processing batch 32: documents 311 to 320
# ✓ Batch completed successfully
# Processing batch 33: documents 321 to 330
# ✓ Batch completed successfully
# Processing batch 34: documents 331 to 340
# ✓ Batch completed successfully
# Processing batch 35: documents 341 to 350
# ✓ Batch completed successfully
# Processing batch 36: documents 351 to 360
# ✓ Batch completed successfully
# Processing batch 37: documents 361 to 370
# ✓ Batch completed successfully
# Processing batch 38: documents 371 to 380
# ✓ Batch completed successfully
# Processing batch 39: documents 381 to 390
# ✓ Batch completed successfully
# Processing batch 40: documents 391 to 400
# ✓ Batch completed successfully
# Processing batch 41: documents 401 to 410
# ✓ Batch completed successfully
# Processing batch 42: documents 411 to 420
# ✓ Batch completed successfully
# Processing batch 43: documents 421 to 430
# ✓ Batch completed successfully
# Processing batch 44: documents 431 to 440
# ✓ Batch completed successfully
# Processing batch 45: documents 441 to 450
# ✓ Batch completed successfully
# Processing batch 46: documents 451 to 460
# ✓ Batch completed successfully
# Processing batch 47: documents 461 to 470
# ✓ Batch completed successfully
# Processing batch 48: documents 471 to 480
# ✓ Batch completed successfully
# Processing batch 49: documents 481 to 490
# ✓ Batch completed successfully
# Processing batch 50: documents 491 to 500
# ✓ Batch completed successfully
# Processing batch 51: documents 501 to 510
# ✓ Batch completed successfully
# Processing batch 52: documents 511 to 520
# ✓ Batch completed successfully
# Processing batch 53: documents 521 to 530
# ✓ Batch completed successfully
# Processing batch 54: documents 531 to 540
# ✓ Batch completed successfully
# Processing batch 55: documents 541 to 550
# ✓ Batch completed successfully
# Processing batch 56: documents 551 to 560
# ✓ Batch completed successfully
# Processing batch 57: documents 561 to 570
# ✓ Batch completed successfully
# Processing batch 58: documents 571 to 580
# ✓ Batch completed successfully
# Processing batch 59: documents 581 to 590
# ✓ Batch completed successfully
# Processing batch 60: documents 591 to 600
# ✓ Batch completed successfully
# Processing batch 61: documents 601 to 610
# ✓ Batch completed successfully
# Processing batch 62: documents 611 to 620
# ✓ Batch completed successfully
# Processing batch 63: documents 621 to 630
# ✓ Batch completed successfully
# Processing batch 64: documents 631 to 640
# ✓ Batch completed successfully
# Processing batch 65: documents 641 to 650
# ✓ Batch completed successfully
# Processing batch 66: documents 651 to 660
# ✓ Batch completed successfully
# Processing batch 67: documents 661 to 670
# ✓ Batch completed successfully
# Processing batch 68: documents 671 to 680
# ✓ Batch completed successfully
# Processing batch 69: documents 681 to 690
# ✓ Batch completed successfully
# Processing batch 70: documents 691 to 700
# ✓ Batch completed successfully
# Processing batch 71: documents 701 to 710
# ✓ Batch completed successfully
# Processing batch 72: documents 711 to 720
# ✓ Batch completed successfully
# Processing batch 73: documents 721 to 730
# ✓ Batch completed successfully
# Processing batch 74: documents 731 to 740
# ✓ Batch completed successfully
# Processing batch 75: documents 741 to 750
# ✓ Batch completed successfully
# Processing batch 76: documents 751 to 760
# ✓ Batch completed successfully
# Processing batch 77: documents 761 to 770
# ✓ Batch completed successfully
# Processing batch 78: documents 771 to 780
# ✓ Batch completed successfully
# Processing batch 79: documents 781 to 790
# ✓ Batch completed successfully
# Processing batch 80: documents 791 to 800
# ✓ Batch completed successfully
# Processing batch 81: documents 801 to 810
# ✓ Batch completed successfully
# Processing batch 82: documents 811 to 820
# ✓ Batch completed successfully
# Processing batch 83: documents 821 to 830
# ✓ Batch completed successfully
# Processing batch 84: documents 831 to 840
# ✓ Batch completed successfully
# Processing batch 85: documents 841 to 850
# ✓ Batch completed successfully
# Processing batch 86: documents 851 to 860
# ✓ Batch completed successfully
# Processing batch 87: documents 861 to 870
# ✓ Batch completed successfully
# Processing batch 88: documents 871 to 880
# ✓ Batch completed successfully
# Processing batch 89: documents 881 to 890
# ✓ Batch completed successfully
# Processing batch 90: documents 891 to 900
# ✓ Batch completed successfully
# Processing batch 91: documents 901 to 910
# ✓ Batch completed successfully
# Processing batch 92: documents 911 to 920
# ✓ Batch completed successfully
# Processing batch 93: documents 921 to 930
# ✓ Batch completed successfully
# Processing batch 94: documents 931 to 940
# ✓ Batch completed successfully
# Processing batch 95: documents 941 to 950
# ✓ Batch completed successfully
# Processing batch 96: documents 951 to 960
# ✓ Batch completed successfully
# Processing batch 97: documents 961 to 970
# ✓ Batch completed successfully
# Processing batch 98: documents 971 to 980
# ✓ Batch completed successfully
# Processing batch 99: documents 981 to 990
# ✓ Batch completed successfully
# Processing batch 100: documents 991 to 1000
# ✓ Batch completed successfully
# Processing batch 101: documents 1001 to 1010
# ✓ Batch completed successfully
# Processing batch 102: documents 1011 to 1020
# ✓ Batch completed successfully
# Processing batch 103: documents 1021 to 1030
# ✓ Batch completed successfully
# Processing batch 104: documents 1031 to 1040
# ✓ Batch completed successfully
# Processing batch 105: documents 1041 to 1050
# ✓ Batch completed successfully
# Processing batch 106: documents 1051 to 1060
# ✓ Batch completed successfully
# Processing batch 107: documents 1061 to 1070
# ✓ Batch completed successfully
# Processing batch 108: documents 1071 to 1080
# ✓ Batch completed successfully
# Processing batch 109: documents 1081 to 1090
# ✓ Batch completed successfully
# Processing batch 110: documents 1091 to 1100
# ✓ Batch completed successfully
# Processing batch 111: documents 1101 to 1110
# ✓ Batch completed successfully
# Processing batch 112: documents 1111 to 1120
# ✓ Batch completed successfully
# Processing batch 113: documents 1121 to 1130
# ✓ Batch completed successfully
# Processing batch 114: documents 1131 to 1140
# ✓ Batch completed successfully
# Processing batch 115: documents 1141 to 1150
# ✓ Batch completed successfully
# Processing batch 116: documents 1151 to 1160
# ✓ Batch completed successfully
# Processing batch 117: documents 1161 to 1170
# ✓ Batch completed successfully
# Processing batch 118: documents 1171 to 1180
# ✓ Batch completed successfully
# Processing batch 119: documents 1181 to 1190
# ✓ Batch completed successfully
# Processing batch 120: documents 1191 to 1200
# ✓ Batch completed successfully
# Processing batch 121: documents 1201 to 1210
# ✓ Batch completed successfully
# Processing batch 122: documents 1211 to 1220
# ✓ Batch completed successfully
# Processing batch 123: documents 1221 to 1230
# ✓ Batch completed successfully
# Processing batch 124: documents 1231 to 1240
# ✓ Batch completed successfully
# Processing batch 125: documents 1241 to 1250
# ✓ Batch completed successfully
# Processing batch 126: documents 1251 to 1260
# ✓ Batch completed successfully
# Processing batch 127: documents 1261 to 1270
# ✓ Batch completed successfully
# Processing batch 128: documents 1271 to 1280
# ✓ Batch completed successfully
# Processing batch 129: documents 1281 to 1290
# ✓ Batch completed successfully
# Processing batch 130: documents 1291 to 1300
# ✓ Batch completed successfully
# Processing batch 131: documents 1301 to 1310
# ✓ Batch completed successfully
# Processing batch 132: documents 1311 to 1320
# ✓ Batch completed successfully
# Processing batch 133: documents 1321 to 1330
# ✓ Batch completed successfully
# Processing batch 134: documents 1331 to 1340
# ✓ Batch completed successfully
# Processing batch 135: documents 1341 to 1350
# ✓ Batch completed successfully
# Processing batch 136: documents 1351 to 1360
# ✓ Batch completed successfully
# Processing batch 137: documents 1361 to 1370
# ✓ Batch completed successfully
# Processing batch 138: documents 1371 to 1380
# ✓ Batch completed successfully
# Processing batch 139: documents 1381 to 1390
# ✓ Batch completed successfully
# Processing batch 140: documents 1391 to 1400
# ✓ Batch completed successfully
# Processing batch 141: documents 1401 to 1410
# ✓ Batch completed successfully
# Processing batch 142: documents 1411 to 1420
# ✓ Batch completed successfully
# Processing batch 143: documents 1421 to 1430
# ✓ Batch completed successfully
# Processing batch 144: documents 1431 to 1440
# ✓ Batch completed successfully
# Processing batch 145: documents 1441 to 1450
# ✓ Batch completed successfully
# Processing batch 146: documents 1451 to 1460
# ✓ Batch completed successfully
# Processing batch 147: documents 1461 to 1470
# ✓ Batch completed successfully
# Processing batch 148: documents 1471 to 1480
# ✓ Batch completed successfully
# Processing batch 149: documents 1481 to 1490
# ✓ Batch completed successfully
# Processing batch 150: documents 1491 to 1500
# ✓ Batch completed successfully
# Processing batch 151: documents 1501 to 1510
# ✓ Batch completed successfully
# Processing batch 152: documents 1511 to 1520
# ✓ Batch completed successfully
# Processing batch 153: documents 1521 to 1530
# ✓ Batch completed successfully
# Processing batch 154: documents 1531 to 1540
# ✓ Batch completed successfully
# Processing batch 155: documents 1541 to 1550
# ✓ Batch completed successfully
# Processing batch 156: documents 1551 to 1560
# ✓ Batch completed successfully
# Processing batch 157: documents 1561 to 1570
# ✓ Batch completed successfully
# Processing batch 158: documents 1571 to 1580
# ✓ Batch completed successfully
# Processing batch 159: documents 1581 to 1590
# ✓ Batch completed successfully
# Processing batch 160: documents 1591 to 1600
# ✓ Batch completed successfully
# Processing batch 161: documents 1601 to 1610
# ✓ Batch completed successfully
# Processing batch 162: documents 1611 to 1620
# ✓ Batch completed successfully
# Processing batch 163: documents 1621 to 1630
# ✓ Batch completed successfully
# Processing batch 164: documents 1631 to 1640
# ✓ Batch completed successfully
# Processing batch 165: documents 1641 to 1650
# ✓ Batch completed successfully
# Processing batch 166: documents 1651 to 1660
# ✓ Batch completed successfully
# Processing batch 167: documents 1661 to 1670
# ✓ Batch completed successfully
# Processing batch 168: documents 1671 to 1680
# ✓ Batch completed successfully
# Processing batch 169: documents 1681 to 1690
# ✓ Batch completed successfully
# Processing batch 170: documents 1691 to 1700
# ✓ Batch completed successfully
# Processing batch 171: documents 1701 to 1710
# ✓ Batch completed successfully
# Processing batch 172: documents 1711 to 1720
# ✓ Batch completed successfully
# Processing batch 173: documents 1721 to 1730
# ✓ Batch completed successfully
# Processing batch 174: documents 1731 to 1740
# ✓ Batch completed successfully
# Processing batch 175: documents 1741 to 1750
# ✓ Batch completed successfully
# Processing batch 176: documents 1751 to 1760
# ✓ Batch completed successfully
# Processing batch 177: documents 1761 to 1770
# ✓ Batch completed successfully
# Processing batch 178: documents 1771 to 1780
# ✓ Batch completed successfully
# Processing batch 179: documents 1781 to 1790
# ✓ Batch completed successfully
# Processing batch 180: documents 1791 to 1800
# ✓ Batch completed successfully
# Processing batch 181: documents 1801 to 1810
# ✓ Batch completed successfully
# Processing batch 182: documents 1811 to 1820
# ✓ Batch completed successfully
# Processing batch 183: documents 1821 to 1830
# ✓ Batch completed successfully
# Processing batch 184: documents 1831 to 1840
# ✓ Batch completed successfully
# Processing batch 185: documents 1841 to 1850
# ✓ Batch completed successfully
# Processing batch 186: documents 1851 to 1860
# ✓ Batch completed successfully
# Processing batch 187: documents 1861 to 1870
# ✓ Batch completed successfully
# Processing batch 188: documents 1871 to 1880
# ✓ Batch completed successfully
# Processing batch 189: documents 1881 to 1890
# ✓ Batch completed successfully
# Processing batch 190: documents 1891 to 1900
# ✓ Batch completed successfully
# Processing batch 191: documents 1901 to 1910
# ✓ Batch completed successfully
# Processing batch 192: documents 1911 to 1920
# ✓ Batch completed successfully
# Processing batch 193: documents 1921 to 1930
# ✓ Batch completed successfully
# Processing batch 194: documents 1931 to 1940
# ✓ Batch completed successfully
# Processing batch 195: documents 1941 to 1950
# ✓ Batch completed successfully
# Processing batch 196: documents 1951 to 1960
# ✓ Batch completed successfully
# Processing batch 197: documents 1961 to 1970
# ✓ Batch completed successfully
# Processing batch 198: documents 1971 to 1980
# ✓ Batch completed successfully
# Processing batch 199: documents 1981 to 1987
# ✓ Batch completed successfully
# ✓ All documents processed!

# %%
test_queries = [
    "apple leaf spot disease symptoms",  
]

# %%
for query in test_queries:
    print(f"\n{'='*60}")
    print(f"Query: {query}")
    print(f"{'='*60}")
   
    # Simple similarity search (top 3 results)
    results = vector_store.similarity_search(query, k=10)
   
    for i, doc in enumerate(results, 1):
        doc_type = doc.metadata['doc_type']
        print(f"\nResult {i} ({doc_type}):")
       
        if doc_type == "product":
            print(f"Product: {doc.metadata['product_name']}")
            print(f"Group: {doc.metadata['group']}")
        else:
            print(f"Plant: {doc.metadata['plant_name']}")
            print(f"Section: {doc.metadata['section']}")
       
        print(f"Content: {doc.page_content[:300]}...")
# Out:
# ============================================================
# Query: apple leaf spot disease symptoms
# ============================================================
#
# Result 1 (plant_info):
# Plant: cherry (including sour)
# Section: Diseases - Cherry leaf spot Coccomyces hiemalis
# Content: - Symptoms: Small, red-purple spots on upper surfaces of leaves which turn brown and may coalesce; leaves may become chlorotic if there are a few lesions present; if tree becomes severely defoliated fruit may fail to develop properly and remain light in color and watery in texture
# - Cause: Fungus ...
#
# Result 2 (plant_info):
# Plant: cashew nuts
# Section: Diseases - Anthracnose Colletotrichum gloeosporoides
# Content: - Symptoms: Water-soaked lesions on leaves, twigs, flowers or young apples which develop into orange-brown or red lesions;
# - Cause: Fungus
# - Comments: Disease emergence favored by rainfall and high humidity
# - Management: Management A protective coating of copper-based fungicide on susceptible ...
#
# Result 3 (plant_info):
# Plant: quince
# Section: Diseases - Leaf blight (Leaf fleck) Diplocarpon maculatum
# Content: - Symptoms: Dark red spots on leaves; brown spots on leaves; leaves dropping from plant; small, raised purple spots with white centre on leaves; dark brown spots on leaves; no fruit produced; tree defoliation
# - Cause: Fungus
# - Comments: Fungus survives on plant debris
# - Management: Management ...
#
# Result 4 (plant_info):
# Plant: pecan
# Section: Diseases - Zonate leaf spot Grovesinia pyramidalis
# Content: - Symptoms: Lesions with concentric rings on leaves which are tan to light brown on the leaf underside and gray-brown on the upper leaf surface; a crystalline substance may be present on the surface of the lesion; infected leaves dry out by late summer and drop from the tree prematurely; defoliation...
#
# Result 5 (plant_info):
# Plant: apple
# Section: Diseases - Cedar apple rust Gymnosporangium juniperi-virginianae
# Content: - Symptoms: Bright orange or yellow patches on top side of leaves surrounded by a red band and small black spots in the center; by mid-summer, cup-like structures called aecia form on the leaf undersides; these become covered in tubular structures from which spores are released.
# - Cause: Fungus
# ...
#
# Result 6 (plant_info):
# Plant: apple
# Section: Diseases - Cedar apple rust Gymnosporangium juniperi-virginianae
# Content: - Symptoms: Bright orange or yellow patches on top side of leaves surrounded by a red band and small black spots in the center; by mid-summer, cup-like structures called aecia form on the leaf undersides; these become covered in tubular structures from which spores are released.
# - Cause: Fungus
# ...
#
# Result 7 (plant_info):
# Plant: orange
# Section: Diseases - Melanose Diaporthe citri
# Content: - Symptoms: Small brown sunken spots which become raised and surrounded by a yellow halo; lesions eventually turn corky in texture; severe infections can cause newly emerging leaves to be crinkled and distorted; if infection of fruit occurs soon after petal fall, the pathogen causes large lesions on...
#
# Result 8 (plant_info):
# Plant: papaya (pawpaw)
# Section: Diseases - Black spot Asperisporium caricae
# Content: - Symptoms: Circular water-soaked or brown lesions on older leaves; centers of lesions become bleached as they mature; leaves curling and turning brown; raised lesions on trunks; sunken circular lesions on fruit.
# - Cause: Fungus
# - Comments: Disease spread by wind and rain; disease emergence favo...
#
# Result 9 (plant_info):
# Plant: lime, sour
# Section: Diseases - Melanose Diaporthe citri
# Content: - Symptoms: Small brown sunken spots which become raised and surrounded by a yellow halo; lesions eventually turn corky in texture; severe infections can cause newly emerging leaves to be crinkled and distorted; if infection of fruit occurs soon after petal fall, the pathogen causes large lesions on...
#
# Result 10 (plant_info):
# Plant: orange
# Section: Diseases - Anthracnose Colletotrichum gloeosporioides
# Content: - Symptoms: Leaves dropping prematurely; leaves covered in dark fungal spores; red to green or black streaks on the mature fruits
# - Cause: Fungus
# - Comments: Disease common during wet Springs or long periods of wet weather late in season
# - Management: Management If disease is damaging then app...

# %%
def search_plant_info(query, k=3):
    """Search plant information only using metadata filter"""
    filter_dict = {"doc_type": "plant_info"}
    return vector_store.similarity_search(query, k=k, filter=filter_dict)

def search_products(query, k=3):
    """Search products only using metadata filter"""
    filter_dict = {"doc_type": "product"}
    results = vector_store.similarity_search(query, k=k, filter=filter_dict)
    return [
        {"content": doc.page_content, "metadata": doc.metadata}
        for doc in results
    ]

def search_disease_info(query, plant_name=None, k=3):
    """Search disease-specific info using metadata filter"""
    filter_dict = {"doc_type": "plant_info"}
    
    if plant_name:
        filter_dict["plant_name"] = plant_name
    
    return vector_store.similarity_search(query, k=k, filter=filter_dict)

def search_products_by_group(query, group_name, k=3):
    """Search products by specific group using metadata filter"""
    filter_dict = {
        "doc_type": "product",
        "group": group_name
    }
    return vector_store.similarity_search(query, k=k, filter=filter_dict)

def search_faq(query, k=3):
    """Search FAQ documents only using metadata filter"""
    filter_dict = {"doc_type": "faq"}
    return vector_store.similarity_search(query, k=k, filter=filter_dict)

# %%
# Test FAQ search
print(f"\n{'='*60}")
print("FAQ Search Test")
print(f"{'='*60}")

faq_test_queries = [
    "bagaimana cara menggunakan dr lensi",
    "apa itu lensfolia",
    "fitur utama lensfolia"
]

for query in faq_test_queries:
    print(f"\nFAQ Query: {query}")
    faq_results = search_faq(query, k=2)
    
    for i, doc in enumerate(faq_results, 1):
        print(f"\nFAQ Result {i}:")
        print(f"{doc.page_content[:300]}...")
# Out:
# ============================================================
# FAQ Search Test
# ============================================================
#
# FAQ Query: bagaimana cara menggunakan dr lensi
#
# FAQ Result 1:
# Q: Bagaimana cara menggunakan Dr. Lensi?
#
# A: 1. Ambil atau unggah gambar tanaman yang sakit.
# 2. Dr. Lensi akan menganalisis gambar dan memberikan hasil diagnosis.
# 3. Lihat ringkasan penyakit, tips perawatan, dan rekomendasi produk....
#
# FAQ Result 2:
# Q: Apakah Dr. Lensi bisa mendeteksi semua jenis tanaman?
#
# A: Model klasifikasi gambar saat ini hanya mencakup beberapa jenis tanaman. Namun, Dr. Lensi tetap dapat memberikan informasi penyakit lainnya melalui pencarian dokumen dan web....
#
# FAQ Query: apa itu lensfolia
#
# FAQ Result 1:
# Q: Apa itu LensFolia?
#
# A: LensFolia adalah aplikasi diagnosis penyakit tanaman berbasis AI (Artificial Intelligence). Aplikasi ini membantu pengguna mengidentifikasi penyakit tanaman melalui gambar dan memberikan informasi lengkap, tips perawatan, serta rekomendasi produk....
#
# FAQ Result 2:
# Q: Apakah LensFolia gratis?
#
# A: Sebagian besar fitur tersedia secara gratis. Namun, beberapa fitur lanjutan atau produk rekomendasi mungkin memerlukan biaya tambahan....
#
# FAQ Query: fitur utama lensfolia
#
# FAQ Result 1:
# Q: Fitur Utama LensFolia?
#
# A: LensFolia memiliki tiga fitur utama:
# **Dr. Lensi**
# Dr. Lensi adalah agen AI cerdas yang dapat:
# - Mendeteksi objek dan penyakit pada tanaman dari gambar.
# - Menggunakan pencarian web dan dokumen untuk memberikan informasi penyakit yang lebih luas.
# - Menyediakan ringka...
#
# FAQ Result 2:
# Q: Apakah LensFolia gratis?
#
# A: Sebagian besar fitur tersedia secara gratis. Namun, beberapa fitur lanjutan atau produk rekomendasi mungkin memerlukan biaya tambahan....

# %%
# Test search
print(f"\n{'='*60}")
print("Test Search Test")
print(f"{'='*60}")

test_queries = [
    "Insektisida untuk tanaman tomat",
]

for query in test_queries:
    print(f"\nQuery: {query}")
    product_results = search_products(query, k=2)
    
    for i, doc in enumerate(product_results, 1):
        print(f"\nResult {i}:")
        print(f"Product Name: {doc['metadata'].get('product_name', 'N/A')}")
        print(f"Group: {doc['metadata'].get('group', 'N/A')}")
        print(f"Content: {doc['content'][:300]}...")
# Out:
# ============================================================
# Test Search Test
# ============================================================
#
# Query: Insektisida untuk tanaman tomat
#
# Result 1:
# Product Name: BENTO 50 EC
# Group: insektisida
# Content: ![Image of product: BENTO 50 EC](https://kresna.co.id/sarikresnakimia/wp-content/uploads/2014/11/Bento-50-EC-1000x1000-360x360.png)
# **Bahan Aktif:** Sipermetrin 50 g/l
# **Deskripsi:** Insektisida racun kontak dan lambung, berbentuk pekatan berwarna kuning yang dapat membentuk emulsi dalam air unt...
#
# Result 2:
# Product Name: MATARIN 50 EC
# Group: insektisida
# Content: ![Image of product: MATARIN 50 EC](https://kresna.co.id/sarikresnakimia/wp-content/uploads/2014/11/Matarin-50-EC-1000x1000-360x360.png)
# **Bahan Aktif:** Lamda sihalotrin 50 g/l
# **Deskripsi:** Insektisida racun kontak dan lambung berbentuk pekatan yang dapat di emulsikan dalam air, berwarna kunin...

# %%
# Agent 1 output simulation: "apple leaf spot detected"
detected_plant = "apple"
detected_disease = "leaf spot"

# Agent 2: Get plant disease info
print(f"\nAgent 2 - Plant disease info for {detected_plant} {detected_disease}:")
plant_results = search_disease_info(f"{detected_plant} {detected_disease}", detected_plant)

for doc in plant_results[:1]:
    print(f"Plant: {doc.metadata['plant_name']}")
    print(f"Content: {doc.page_content[:400]}...")

# Agent 3: Get product recommendations
print(f"\nAgent 3 - Product recommendations for {detected_disease}:")
product_results = search_products(f"fungicide {detected_disease}")

for doc in product_results[:1]:
    print(f"Product: {doc.metadata['product_name']}")
    print(f"Group: {doc.metadata['group']}")
    print(f"Content: {doc.page_content[:400]}...")
# Out:
# Agent 2 - Plant disease info for apple leaf spot:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 7
#       5 # Agent 2: Get plant disease info
#       6 print(f"\nAgent 2 - Plant disease info for {detected_plant} {detected_disease}:")
# ----> 7 plant_results = search_disease_info(f"{detected_plant} {detected_disease}", detected_plant)
#       9 for doc in plant_results[:1]:
#      10     print(f"Plant: {doc.metadata['plant_name']}")
#
# Cell In[10], line 22, in search_disease_info(query, plant_name, k)
#      19 if plant_name:
#      20     filter_dict["plant_name"] = plant_name
# ---> 22 return vector_store.similarity_search(query, k=k, filter=filter_dict)
#
# File ~/workspace/repos/reaksijs-fit2025/research/.lensfolia-research-venv/lib/python3.11/site-packages/langchain_community/vectorstores/supabase.py:183, in SupabaseVectorStore.similarity_search(self, query, k, filter, **kwargs)
#     176 def similarity_search(
#     177     self,
#     178     query: str,
#    (...)    181     **kwargs: Any,
#     182 ) -> List[Document]:
# --> 183     vector = self._embedding.embed_query(query)
#     184     return self.similarity_search_by_vector(vector, k=k, filter=filter, **kwargs)
#
# File ~/workspace/repos/reaksijs-fit2025/research/.lensfolia-research-venv/lib/python3.11/site-packages/langchain_google_genai/embeddings.py:281, in GoogleGenerativeAIEmbeddings.embed_query(self, text, task_type, title, output_dimensionality)
#     274 try:
#     275     request: EmbedContentRequest = self._prepare_request(
#     276         text=text,
#     277         task_type=task_type,
#     278         title=title,
#     279         output_dimensionality=output_dimensionality,
#     280     )
# --> 281     result: EmbedContentResponse = self.client.embed_content(request)
#     282 except Exception as e:
#     283     raise GoogleGenerativeAIError(f"Error embedding content: {e}") from e
#
# File ~/workspace/repos/reaksijs-fit2025/research/.lensfolia-research-venv/lib/python3.11/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py:1305, in GenerativeServiceClient.embed_content(self, request, model, content, retry, timeout, metadata)
#    1302 self._validate_universe_domain()
#    1304 # Send the request.
# -> 1305 response = rpc(
#    1306     request,
#    1307     retry=retry,
#    1308     timeout=timeout,
#    1309     metadata=metadata,
#    1310 )
#    1312 # Done; return the response.
#    1313 return response
#
# File ~/workspace/repos/reaksijs-fit2025/research/.lensfolia-research-venv/lib/python3.11/site-packages/google/api_core/gapic_v1/method.py:131, in _GapicCallable.__call__(self, timeout, retry, compression, *args, **kwargs)
#     128 if self._compression is not None:
#     129     kwargs["compression"] = compression
# --> 131 return wrapped_func(*args, **kwargs)
#
# File ~/workspace/repos/reaksijs-fit2025/research/.lensfolia-research-venv/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py:294, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     290 target = functools.partial(func, *args, **kwargs)
#     291 sleep_generator = exponential_sleep_generator(
#     292     self._initial, self._maximum, multiplier=self._multiplier
#     293 )
# --> 294 return retry_target(
#     295     target,
#     296     self._predicate,
#     297     sleep_generator,
#     298     timeout=self._timeout,
#     299     on_error=on_error,
#     300 )
#
# File ~/workspace/repos/reaksijs-fit2025/research/.lensfolia-research-venv/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py:147, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     145 while True:
#     146     try:
# --> 147         result = target()
#     148         if inspect.isawaitable(result):
#     149             warnings.warn(_ASYNC_RETRY_WARNING)
#
# File ~/workspace/repos/reaksijs-fit2025/research/.lensfolia-research-venv/lib/python3.11/site-packages/google/api_core/timeout.py:130, in TimeToDeadlineTimeout.__call__.<locals>.func_with_timeout(*args, **kwargs)
#     126         remaining_timeout = self._timeout
#     128     kwargs["timeout"] = remaining_timeout
# --> 130 return func(*args, **kwargs)
#
# File ~/workspace/repos/reaksijs-fit2025/research/.lensfolia-research-venv/lib/python3.11/site-packages/google/api_core/grpc_helpers.py:76, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      73 @functools.wraps(callable_)
#      74 def error_remapped_callable(*args, **kwargs):
#      75     try:
# ---> 76         return callable_(*args, **kwargs)
#      77     except grpc.RpcError as exc:
#      78         raise exceptions.from_grpc_error(exc) from exc
#
# File ~/workspace/repos/reaksijs-fit2025/research/.lensfolia-research-venv/lib/python3.11/site-packages/grpc/_interceptor.py:277, in _UnaryUnaryMultiCallable.__call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     268 def __call__(
#     269     self,
#     270     request: Any,
#    (...)    275     compression: Optional[grpc.Compression] = None,
#     276 ) -> Any:
# --> 277     response, ignored_call = self._with_call(
#     278         request,
#     279         timeout=timeout,
#     280         metadata=metadata,
#     281         credentials=credentials,
#     282         wait_for_ready=wait_for_ready,
#     283         compression=compression,
#     284     )
#     285     return response
#
# File ~/workspace/repos/reaksijs-fit2025/research/.lensfolia-research-venv/lib/python3.11/site-packages/grpc/_interceptor.py:329, in _UnaryUnaryMultiCallable._with_call(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     326     except Exception as exception:  # pylint:disable=broad-except
#     327         return _FailureOutcome(exception, sys.exc_info()[2])
# --> 329 call = self._interceptor.intercept_unary_unary(
#     330     continuation, client_call_details, request
#     331 )
#     332 return call.result(), call
#
# File ~/workspace/repos/reaksijs-fit2025/research/.lensfolia-research-venv/lib/python3.11/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/transports/grpc.py:78, in _LoggingClientInterceptor.intercept_unary_unary(self, continuation, client_call_details, request)
#      64     grpc_request = {
#      65         "payload": request_payload,
#      66         "requestMethod": "grpc",
#      67         "metadata": dict(request_metadata),
#      68     }
#      69     _LOGGER.debug(
#      70         f"Sending request for {client_call_details.method}",
#      71         extra={
#    (...)     76         },
#      77     )
# ---> 78 response = continuation(client_call_details, request)
#      79 if logging_enabled:  # pragma: NO COVER
#      80     response_metadata = response.trailing_metadata()
#
# File ~/workspace/repos/reaksijs-fit2025/research/.lensfolia-research-venv/lib/python3.11/site-packages/grpc/_interceptor.py:315, in _UnaryUnaryMultiCallable._with_call.<locals>.continuation(new_details, request)
#     306 (
#     307     new_method,
#     308     new_timeout,
#    (...)    312     new_compression,
#     313 ) = _unwrap_client_call_details(new_details, client_call_details)
#     314 try:
# --> 315     response, call = self._thunk(new_method).with_call(
#     316         request,
#     317         timeout=new_timeout,
#     318         metadata=new_metadata,
#     319         credentials=new_credentials,
#     320         wait_for_ready=new_wait_for_ready,
#     321         compression=new_compression,
#     322     )
#     323     return _UnaryOutcome(response, call)
#     324 except grpc.RpcError as rpc_error:
#
# File ~/workspace/repos/reaksijs-fit2025/research/.lensfolia-research-venv/lib/python3.11/site-packages/grpc/_channel.py:1189, in _UnaryUnaryMultiCallable.with_call(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1180 def with_call(
#    1181     self,
#    1182     request: Any,
#    (...)   1187     compression: Optional[grpc.Compression] = None,
#    1188 ) -> Tuple[Any, grpc.Call]:
# -> 1189     state, call = self._blocking(
#    1190         request, timeout, metadata, credentials, wait_for_ready, compression
#    1191     )
#    1192     return _end_unary_response_blocking(state, call, True, None)
#
# File ~/workspace/repos/reaksijs-fit2025/research/.lensfolia-research-venv/lib/python3.11/site-packages/grpc/_channel.py:1162, in _UnaryUnaryMultiCallable._blocking(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1145 state.target = _common.decode(self._target)
#    1146 call = self._channel.segregated_call(
#    1147     cygrpc.PropagationConstants.GRPC_PROPAGATE_DEFAULTS,
#    1148     self._method,
#    (...)   1160     self._registered_call_handle,
#    1161 )
# -> 1162 event = call.next_event()
#    1163 _handle_event(event, state, self._response_deserializer)
#    1164 return state, call
#
# File src/python/grpcio/grpc/_cython/_cygrpc/channel.pyx.pxi:388, in grpc._cython.cygrpc.SegregatedCall.next_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/channel.pyx.pxi:211, in grpc._cython.cygrpc._next_call_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/channel.pyx.pxi:205, in grpc._cython.cygrpc._next_call_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/completion_queue.pyx.pxi:97, in grpc._cython.cygrpc._latent_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/completion_queue.pyx.pxi:80, in grpc._cython.cygrpc._internal_latent_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/completion_queue.pyx.pxi:61, in grpc._cython.cygrpc._next()
#
# KeyboardInterrupt:
